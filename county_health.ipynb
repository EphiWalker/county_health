# %% [markdown]
# <a href="https://colab.research.google.com/github/EphiWalker/county_health/blob/main/county_health.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Maryland Counties' Health Metrics Analysis

# %% [markdown]
# For this project, I'll be using datasets from [countyhealthrankings.org](https://www.countyhealthrankings.org) to perform analysis & visualization as well as draw conclusions about the health ranking's of counties in the US. I'll also be doing a more-focused analysis on Montgomery County, Maryland (where I live) to make the whole analysis more relatable in my context.
#
# For a direct link to the datasets, click [here](https://www.countyhealthrankings.org/explore-health-rankings/rankings-data-documentation). Among the data listed on the website, the '2023 County Health Rankings National Data' dataset will be the specific one that I'll use for this project.
#
# [age-adjusted death rates](https://health.mo.gov/data/mica/CDP_MICA/AARate.html)
#
# ACSC hospitalization rates are a well-established parameter for assessing the performance of primary health care (PHC)
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9367847/

# %% [markdown]
# ##Objectives
# * Data Cleaning & Preprocessing
# * Data Visualization
# * Drawing Conclusions (Answering Research Questions)

# %% [markdown]
# ###Research Questions
# 1. Which county performed best in
# 2. Among all the features, which are the top five indicators of superior health?
# 3. Something about Montgomery County

# %%
#import warnings
#warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd


df_url = 'https://github.com/EphiWalker/datasets/raw/main/county_health_2023.xlsx'
df_1 = pd.read_excel(df_url, sheet_name='Ranked Measure Data')
df_2 = pd.read_excel(df_url, sheet_name='Additional Measure Data')

# %%
df_1.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Premature Death Unnamed: 4  \
# 0       FIPS      State     County      Unreliable     Deaths
# 1      01000    Alabama        NaN             NaN      88086
# 2      01001    Alabama    Autauga             NaN        836
# 3      01003    Alabama    Baldwin             NaN       3377
# 4      01005    Alabama    Barbour             NaN        539
#
#                           Unnamed: 5    Unnamed: 6     Unnamed: 7 Unnamed: 8  \
# 0  Years of Potential Life Lost Rate  95% CI - Low  95% CI - High   Quartile
# 1                       10350.071456  10246.133257   10454.009654        NaN
# 2                        8027.394727   7197.625811    8857.163642          1
# 3                        8118.358206   7666.874101    8569.842311          1
# 4                       12876.760319  11149.914146   14603.606492          4
#
#          Unnamed: 9  ...                           Unnamed: 236  \
# ...

# %%
df_1['FIPS']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FIPS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
from pandas.core.dtypes.missing import isna
#df_1[df_1['Premature Death'] != 'Nan']
df_1[df_1['Premature Death'].isna()==False]

# %%
df_2.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  Life Expectancy    Unnamed: 4  \
# 0       FIPS      State     County  Life Expectancy  95% CI - Low
# 1      01000    Alabama        NaN        74.835949     74.753991
# 2      01001    Alabama    Autauga         76.58565     75.847961
# 3      01003    Alabama    Baldwin        77.724729     77.338977
# 4      01005    Alabama    Barbour         72.86721     71.635872
#
#       Unnamed: 5              Unnamed: 6                           Unnamed: 7  \
# 0  95% CI - High  Life Expectancy (AIAN)  Life Expectancy (AIAN) 95% CI - Low
# 1      74.917907              111.782702                            99.279703
# 2      77.323338                     NaN                                  NaN
# 3      78.110481              104.617932                            67.626451
# 4      74.098549                     NaN                                  NaN
#
#                              Unnamed: 8               Unnamed: 9  ...  \
# ...
